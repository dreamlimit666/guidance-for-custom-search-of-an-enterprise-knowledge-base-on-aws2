# %%
# !pip install --upgrade boto3
# !pip install --upgrade sagemaker
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (1.28.27)
# Collecting boto3
#   Downloading boto3-1.28.48-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from boto3) (1.0.1)
# Collecting botocore<1.32.0,>=1.31.48
#   Downloading botocore-1.31.48-py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 109.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from boto3) (0.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore<1.32.0,>=1.31.48->boto3) (1.26.15)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore<1.32.0,>=1.31.48->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.32.0,>=1.31.48->boto3) (1.16.0)
# Installing collected packages: botocore, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.31.27
#     Uninstalling botocore-1.31.27:
#       Successfully uninstalled botocore-1.31.27
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.28.27
#     Uninstalling boto3-1.28.27:
#       Successfully uninstalled boto3-1.28.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.27.114 requires botocore==1.29.114, but you have botocore 1.31.48 which is incompatible.
# awscli 1.27.114 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0.1 which is incompatible.
# Successfully installed boto3-1.28.48 botocore-1.31.48
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (2.177.1)
# Collecting sagemaker
#   Downloading sagemaker-2.186.0.tar.gz (885 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 885.1/885.1 kB 11.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs<24,>=23.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (23.1.0)
# Requirement already satisfied: boto3<2.0,>=1.26.131 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (1.28.48)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (2.2.1)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (1.25.2)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (3.20.2)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (4.13.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (1.4.4)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (0.3.0)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (0.7.5)
# Requirement already satisfied: PyYAML~=6.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (6.0.1)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (3.2.0)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (2.6.2)
# Requirement already satisfied: tblib==1.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker) (1.7.0)
# Requirement already satisfied: botocore<1.32.0,>=1.31.48 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from boto3<2.0,>=1.26.131->sagemaker) (1.31.48)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from boto3<2.0,>=1.26.131->sagemaker) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from boto3<2.0,>=1.26.131->sagemaker) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from packaging>=20.0->sagemaker) (3.0.9)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from jsonschema->sagemaker) (0.19.3)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from jsonschema->sagemaker) (65.6.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pandas->sagemaker) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pandas->sagemaker) (2022.7)
# Requirement already satisfied: dill>=0.3.6 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker) (0.3.6)
# Requirement already satisfied: ppft>=1.7.6.6 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker) (1.7.6.6)
# Requirement already satisfied: multiprocess>=0.70.14 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker) (0.70.14)
# Requirement already satisfied: pox>=0.3.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker) (0.3.2)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from schema->sagemaker) (21.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore<1.32.0,>=1.31.48->boto3<2.0,>=1.26.131->sagemaker) (1.26.15)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.186.0-py2.py3-none-any.whl size=1185877 sha256=6039c0cef7edfe147751f4057f9be7d5dd777a2036e014de82d9e65504e226bf
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/a7/6f/ec/20d31846d6b6a287c4c4dc5efec2248a7acb4e398bc66bde4c
# Successfully built sagemaker
# Installing collected packages: sagemaker
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.177.1
#     Uninstalling sagemaker-2.177.1:
#       Successfully uninstalled sagemaker-2.177.1
# Successfully installed sagemaker-2.186.0

# %%
# For notebook instances (Amazon Linux)
# !sudo yum update -y
# !sudo yum install amazon-linux-extras
# !sudo amazon-linux-extras install epel -y
# !sudo yum update -y
# !sudo yum install git-lfs git -y
# Out:
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-epel                                          | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# epel/x86_64/metalink                                     |  25 kB     00:00
# epel                                                     | 4.7 kB     00:00
# github_git-lfs/x86_64/signature                          |  819 B     00:00
# github_git-lfs/x86_64/signature                          |  951 B     00:00 !!!
# github_git-lfs-source/signature                          |  819 B     00:00
# github_git-lfs-source/signature                          |  951 B     00:00 !!!
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# (1/4): epel/x86_64/group_gz                                |  99 kB   00:00
# (2/4): epel/x86_64/updateinfo                              | 1.0 MB   00:00
# (3/4): epel/x86_64/primary_db                              | 7.0 MB   00:00
# (4/4): neuron/primary_db                                   | 145 kB   00:00
# 286 packages excluded due to repository priority protections
# Resolving Dependencies
# --> Running transaction check
# ---> Package amazon-cloudwatch-agent.x86_64 0:1.300025.0-1.amzn2 will be updated
# ---> Package amazon-cloudwatch-agent.x86_64 0:1.300026.3-2.amzn2 will be an update
# ---> Package amazon-ssm-agent.x86_64 0:3.2.815.0-1 will be updated
# ---> Package amazon-ssm-agent.x86_64 0:3.2.1377.0-1.amzn2 will be an update
# ---> Package bind-export-libs.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be updated
# ---> Package bind-export-libs.x86_64 32:9.11.4-26.P2.amzn2.13.4 will be an update
# ---> Package bind-libs.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be updated
# ---> Package bind-libs.x86_64 32:9.11.4-26.P2.amzn2.13.4 will be an update
# ---> Package bind-libs-lite.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be updated
# ---> Package bind-libs-lite.x86_64 32:9.11.4-26.P2.amzn2.13.4 will be an update
# ---> Package bind-license.noarch 32:9.11.4-26.P2.amzn2.13.1 will be updated
# ---> Package bind-license.noarch 32:9.11.4-26.P2.amzn2.13.4 will be an update
# ---> Package bind-utils.x86_64 32:9.11.4-26.P2.amzn2.13.1 will be updated
# ---> Package bind-utils.x86_64 32:9.11.4-26.P2.amzn2.13.4 will be an update
# ---> Package ca-certificates.noarch 0:2021.2.50-72.amzn2.0.7 will be updated
# ---> Package ca-certificates.noarch 0:2021.2.50-72.amzn2.0.8 will be an update
# ---> Package containerd.x86_64 0:1.6.19-1.amzn2.0.1 will be updated
# ---> Package containerd.x86_64 0:1.6.19-1.amzn2.0.3 will be an update
# ---> Package cpp.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package cpp.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package cpp10.x86_64 0:10.4.0-1.amzn2.0.1 will be updated
# ---> Package cpp10.x86_64 0:10.5.0-1.amzn2.0.2 will be an update
# ---> Package cups-libs.x86_64 1:1.6.3-51.amzn2.0.2 will be updated
# ---> Package cups-libs.x86_64 1:1.6.3-51.amzn2.0.3 will be an update
# ---> Package curl.x86_64 0:8.0.1-1.amzn2.0.1 will be updated
# ---> Package curl.x86_64 0:8.2.1-1.amzn2.0.3 will be an update
# ---> Package dhclient.x86_64 12:4.2.5-79.amzn2.1.2 will be updated
# ---> Package dhclient.x86_64 12:4.2.5-79.amzn2.1.5 will be an update
# ---> Package dhcp-common.x86_64 12:4.2.5-79.amzn2.1.2 will be updated
# ---> Package dhcp-common.x86_64 12:4.2.5-79.amzn2.1.5 will be an update
# ---> Package dhcp-libs.x86_64 12:4.2.5-79.amzn2.1.2 will be updated
# ---> Package dhcp-libs.x86_64 12:4.2.5-79.amzn2.1.5 will be an update
# ---> Package ec2-hibinit-agent.noarch 0:1.0.2-4.amzn2 will be updated
# ---> Package ec2-hibinit-agent.noarch 0:1.0.2-5.amzn2 will be an update
# ---> Package gcc.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package gcc.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package gcc-c++.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package gcc-c++.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package gcc-gfortran.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package gcc-gfortran.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package gcc10.x86_64 0:10.4.0-1.amzn2.0.1 will be updated
# ---> Package gcc10.x86_64 0:10.5.0-1.amzn2.0.2 will be an update
# ---> Package glibc.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package glibc.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package glibc-all-langpacks.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package glibc-all-langpacks.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package glibc-common.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package glibc-common.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package glibc-devel.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package glibc-devel.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package glibc-headers.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package glibc-headers.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package glibc-locale-source.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package glibc-locale-source.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package glibc-minimal-langpack.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package glibc-minimal-langpack.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package hwloc-libs.x86_64 0:1.11.8-4.amzn2 will be updated
# ---> Package hwloc-libs.x86_64 0:1.11.8-4.amzn2.0.2 will be an update
# ---> Package kernel-devel.x86_64 0:5.10.192-183.736.amzn2 will be installed
# ---> Package kernel-headers.x86_64 0:5.10.186-179.751.amzn2 will be updated
# ---> Package kernel-headers.x86_64 0:5.10.192-183.736.amzn2 will be an update
# ---> Package krb5-devel.x86_64 0:1.15.1-55.amzn2.2.5 will be updated
# ---> Package krb5-devel.x86_64 0:1.15.1-55.amzn2.2.6 will be an update
# ---> Package krb5-libs.x86_64 0:1.15.1-55.amzn2.2.5 will be updated
# ---> Package krb5-libs.x86_64 0:1.15.1-55.amzn2.2.6 will be an update
# ---> Package libatomic.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libatomic.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libcilkrts.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libcilkrts.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libcrypt.x86_64 0:2.26-63.amzn2 will be updated
# ---> Package libcrypt.x86_64 0:2.26-63.amzn2.0.1 will be an update
# ---> Package libcurl.x86_64 0:8.0.1-1.amzn2.0.1 will be updated
# ---> Package libcurl.x86_64 0:8.2.1-1.amzn2.0.3 will be an update
# ---> Package libcurl-devel.x86_64 0:8.0.1-1.amzn2.0.1 will be updated
# ---> Package libcurl-devel.x86_64 0:8.2.1-1.amzn2.0.3 will be an update
# ---> Package libgcc.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libgcc.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libgfortran.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libgfortran.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libgomp.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libgomp.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libgs.x86_64 0:9.25-5.amzn2.0.3 will be updated
# ---> Package libgs.x86_64 0:9.25-5.amzn2.0.4 will be an update
# ---> Package libidn.x86_64 0:1.28-4.amzn2.0.2 will be updated
# ---> Package libidn.x86_64 0:1.28-4.amzn2.0.5 will be an update
# ---> Package libidn2.x86_64 0:2.3.0-1.amzn2 will be updated
# ---> Package libidn2.x86_64 0:2.3.0-1.amzn2.0.3 will be an update
# ---> Package libitm.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libitm.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libjpeg-turbo.x86_64 0:2.0.90-2.amzn2.0.1 will be updated
# ---> Package libjpeg-turbo.x86_64 0:2.0.90-2.amzn2.0.5 will be an update
# ---> Package libjpeg-turbo-devel.x86_64 0:2.0.90-2.amzn2.0.1 will be updated
# ---> Package libjpeg-turbo-devel.x86_64 0:2.0.90-2.amzn2.0.5 will be an update
# ---> Package libkadm5.x86_64 0:1.15.1-55.amzn2.2.5 will be updated
# ---> Package libkadm5.x86_64 0:1.15.1-55.amzn2.2.6 will be an update
# ---> Package libmpx.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libmpx.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libnghttp2.x86_64 0:1.41.0-1.amzn2.0.1 will be updated
# ---> Package libnghttp2.x86_64 0:1.41.0-1.amzn2.0.3 will be an update
# ---> Package libpng.x86_64 2:1.5.13-8.amzn2.0.1 will be updated
# ---> Package libpng.x86_64 2:1.5.13-8.amzn2.0.5 will be an update
# ---> Package libquadmath.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libquadmath.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libsanitizer.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libsanitizer.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libssh2.x86_64 0:1.4.3-12.amzn2.2.4 will be updated
# ---> Package libssh2.x86_64 0:1.4.3-12.amzn2.2.5 will be an update
# ---> Package libstdc++.x86_64 0:7.3.1-15.amzn2 will be updated
# ---> Package libstdc++.x86_64 0:7.3.1-17.amzn2 will be an update
# ---> Package libtasn1.x86_64 0:4.10-1.amzn2.0.3 will be updated
# ---> Package libtasn1.x86_64 0:4.10-1.amzn2.0.6 will be an update
# ---> Package libtiff.x86_64 0:4.0.3-35.amzn2.0.8 will be updated
# ---> Package libtiff.x86_64 0:4.0.3-35.amzn2.0.12 will be an update
# ---> Package libxml2.x86_64 0:2.9.1-6.amzn2.5.8 will be updated
# ---> Package libxml2.x86_64 0:2.9.1-6.amzn2.5.12 will be an update
# ---> Package libxml2-devel.x86_64 0:2.9.1-6.amzn2.5.8 will be updated
# ---> Package libxml2-devel.x86_64 0:2.9.1-6.amzn2.5.12 will be an update
# ---> Package libxml2-python.x86_64 0:2.9.1-6.amzn2.5.8 will be updated
# ---> Package libxml2-python.x86_64 0:2.9.1-6.amzn2.5.12 will be an update
# ---> Package oniguruma.x86_64 0:5.9.6-1.amzn2.0.4 will be updated
# ---> Package oniguruma.x86_64 0:5.9.6-1.amzn2.0.5 will be an update
# ---> Package openssh.x86_64 0:7.4p1-22.amzn2.0.3 will be updated
# ---> Package openssh.x86_64 0:7.4p1-22.amzn2.0.5 will be an update
# ---> Package openssh-clients.x86_64 0:7.4p1-22.amzn2.0.3 will be updated
# ---> Package openssh-clients.x86_64 0:7.4p1-22.amzn2.0.5 will be an update
# ---> Package openssh-server.x86_64 0:7.4p1-22.amzn2.0.3 will be updated
# ---> Package openssh-server.x86_64 0:7.4p1-22.amzn2.0.5 will be an update
# ---> Package openssl.x86_64 1:1.0.2k-24.amzn2.0.7 will be updated
# ---> Package openssl.x86_64 1:1.0.2k-24.amzn2.0.9 will be an update
# ---> Package openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.7 will be updated
# ---> Package openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.9 will be an update
# ---> Package openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.7 will be updated
# ---> Package openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.9 will be an update
# ---> Package python3.x86_64 0:3.7.16-1.amzn2.0.2 will be updated
# ---> Package python3.x86_64 0:3.7.16-1.amzn2.0.4 will be an update
# ---> Package python3-libs.x86_64 0:3.7.16-1.amzn2.0.2 will be updated
# ---> Package python3-libs.x86_64 0:3.7.16-1.amzn2.0.4 will be an update
# ---> Package python38.x86_64 0:3.8.16-1.amzn2.0.2 will be obsoleted
# ---> Package python38.x86_64 0:3.8.16-1.amzn2.0.5 will be obsoleting
# ---> Package python38-devel.x86_64 0:3.8.16-1.amzn2.0.2 will be updated
# ---> Package python38-devel.x86_64 0:3.8.16-1.amzn2.0.5 will be an update
# ---> Package python38-libs.x86_64 0:3.8.16-1.amzn2.0.2 will be updated
# ---> Package python38-libs.x86_64 0:3.8.16-1.amzn2.0.5 will be an update
# ---> Package runc.x86_64 0:1.1.7-1.amzn2 will be updated
# ---> Package runc.x86_64 0:1.1.7-3.amzn2 will be an update
# ---> Package sudo.x86_64 0:1.8.23-10.amzn2.3.1 will be updated
# ---> Package sudo.x86_64 0:1.8.23-10.amzn2.3.4 will be an update
# ---> Package tensorflow-model-server-neuronx.x86_64 0:2.10.1.2.9.3.0-0 will be updated
# ---> Package tensorflow-model-server-neuronx.x86_64 0:2.10.1.2.10.1.0-0 will be an update
# --> Finished Dependency Resolution
# --> Running transaction check
# ---> Package kernel-devel.x86_64 0:5.10.184-175.731.amzn2 will be erased
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package           Arch   Version                    Repository            Size
# ================================================================================
# Installing:
#  kernel-devel      x86_64 5.10.192-183.736.amzn2     amzn2extra-kernel-5.10
#                                                                            16 M
#  python38          x86_64 3.8.16-1.amzn2.0.5         amzn2extra-python3.8  70 k
#      replacing  python38.x86_64 3.8.16-1.amzn2.0.2
# Updating:
#  amazon-cloudwatch-agent
#                    x86_64 1.300026.3-2.amzn2         amzn2-core            67 M
#  amazon-ssm-agent  x86_64 3.2.1377.0-1.amzn2         amzn2-core            24 M
#  bind-export-libs  x86_64 32:9.11.4-26.P2.amzn2.13.4 amzn2-core           1.1 M
#  bind-libs         x86_64 32:9.11.4-26.P2.amzn2.13.4 amzn2-core           159 k
#  bind-libs-lite    x86_64 32:9.11.4-26.P2.amzn2.13.4 amzn2-core           1.1 M
#  bind-license      noarch 32:9.11.4-26.P2.amzn2.13.4 amzn2-core            92 k
#  bind-utils        x86_64 32:9.11.4-26.P2.amzn2.13.4 amzn2-core           261 k
#  ca-certificates   noarch 2021.2.50-72.amzn2.0.8     amzn2-core           367 k
#  containerd        x86_64 1.6.19-1.amzn2.0.3         amzn2extra-docker     28 M
#  cpp               x86_64 7.3.1-17.amzn2             amzn2-core           9.2 M
#  cpp10             x86_64 10.5.0-1.amzn2.0.2         amzn2-core           9.5 M
#  cups-libs         x86_64 1:1.6.3-51.amzn2.0.3       amzn2-core           356 k
#  curl              x86_64 8.2.1-1.amzn2.0.3          amzn2-core           369 k
#  dhclient          x86_64 12:4.2.5-79.amzn2.1.5      amzn2-core           287 k
#  dhcp-common       x86_64 12:4.2.5-79.amzn2.1.5      amzn2-core           177 k
#  dhcp-libs         x86_64 12:4.2.5-79.amzn2.1.5      amzn2-core           132 k
#  ec2-hibinit-agent noarch 1.0.2-5.amzn2              amzn2-core            15 k
#  gcc               x86_64 7.3.1-17.amzn2             amzn2-core            22 M
#  gcc-c++           x86_64 7.3.1-17.amzn2             amzn2-core            13 M
#  gcc-gfortran      x86_64 7.3.1-17.amzn2             amzn2-core            11 M
#  gcc10             x86_64 10.5.0-1.amzn2.0.2         amzn2-core            38 M
#  glibc             x86_64 2.26-63.amzn2.0.1          amzn2-core           3.3 M
#  glibc-all-langpacks
#                    x86_64 2.26-63.amzn2.0.1          amzn2-core           7.0 M
#  glibc-common      x86_64 2.26-63.amzn2.0.1          amzn2-core           774 k
#  glibc-devel       x86_64 2.26-63.amzn2.0.1          amzn2-core           995 k
#  glibc-headers     x86_64 2.26-63.amzn2.0.1          amzn2-core           516 k
#  glibc-locale-source
#                    x86_64 2.26-63.amzn2.0.1          amzn2-core           3.2 M
#  glibc-minimal-langpack
#                    x86_64 2.26-63.amzn2.0.1          amzn2-core            33 k
#  hwloc-libs        x86_64 1.11.8-4.amzn2.0.2         amzn2-core           1.6 M
#  kernel-headers    x86_64 5.10.192-183.736.amzn2     amzn2extra-kernel-5.10
#                                                                           1.4 M
#  krb5-devel        x86_64 1.15.1-55.amzn2.2.6        amzn2-core           274 k
#  krb5-libs         x86_64 1.15.1-55.amzn2.2.6        amzn2-core           803 k
#  libatomic         x86_64 7.3.1-17.amzn2             amzn2-core            46 k
#  libcilkrts        x86_64 7.3.1-17.amzn2             amzn2-core            85 k
#  libcrypt          x86_64 2.26-63.amzn2.0.1          amzn2-core            53 k
#  libcurl           x86_64 8.2.1-1.amzn2.0.3          amzn2-core           333 k
#  libcurl-devel     x86_64 8.2.1-1.amzn2.0.3          amzn2-core           931 k
#  libgcc            x86_64 7.3.1-17.amzn2             amzn2-core            99 k
#  libgfortran       x86_64 7.3.1-17.amzn2             amzn2-core           536 k
#  libgomp           x86_64 7.3.1-17.amzn2             amzn2-core           205 k
#  libgs             x86_64 9.25-5.amzn2.0.4           amzn2-core           4.5 M
#  libidn            x86_64 1.28-4.amzn2.0.5           amzn2-core           209 k
#  libidn2           x86_64 2.3.0-1.amzn2.0.3          amzn2-core           140 k
#  libitm            x86_64 7.3.1-17.amzn2             amzn2-core            85 k
#  libjpeg-turbo     x86_64 2.0.90-2.amzn2.0.5         amzn2-core           171 k
#  libjpeg-turbo-devel
#                    x86_64 2.0.90-2.amzn2.0.5         amzn2-core           110 k
#  libkadm5          x86_64 1.15.1-55.amzn2.2.6        amzn2-core           181 k
#  libmpx            x86_64 7.3.1-17.amzn2             amzn2-core            52 k
#  libnghttp2        x86_64 1.41.0-1.amzn2.0.3         amzn2-core            72 k
#  libpng            x86_64 2:1.5.13-8.amzn2.0.5       amzn2-core           212 k
#  libquadmath       x86_64 7.3.1-17.amzn2             amzn2-core           189 k
#  libsanitizer      x86_64 7.3.1-17.amzn2             amzn2-core           642 k
#  libssh2           x86_64 1.4.3-12.amzn2.2.5         amzn2-core           136 k
#  libstdc++         x86_64 7.3.1-17.amzn2             amzn2-core           446 k
#  libtasn1          x86_64 4.10-1.amzn2.0.6           amzn2-core           320 k
#  libtiff           x86_64 4.0.3-35.amzn2.0.12        amzn2-core           175 k
#  libxml2           x86_64 2.9.1-6.amzn2.5.12         amzn2-core           661 k
#  libxml2-devel     x86_64 2.9.1-6.amzn2.5.12         amzn2-core           1.1 M
#  libxml2-python    x86_64 2.9.1-6.amzn2.5.12         amzn2-core           247 k
#  oniguruma         x86_64 5.9.6-1.amzn2.0.5          amzn2-core           127 k
#  openssh           x86_64 7.4p1-22.amzn2.0.5         amzn2-core           508 k
#  openssh-clients   x86_64 7.4p1-22.amzn2.0.5         amzn2-core           652 k
#  openssh-server    x86_64 7.4p1-22.amzn2.0.5         amzn2-core           458 k
#  openssl           x86_64 1:1.0.2k-24.amzn2.0.9      amzn2-core           497 k
#  openssl-devel     x86_64 1:1.0.2k-24.amzn2.0.9      amzn2-core           1.5 M
#  openssl-libs      x86_64 1:1.0.2k-24.amzn2.0.9      amzn2-core           1.2 M
#  python3           x86_64 3.7.16-1.amzn2.0.4         amzn2-core            72 k
#  python3-libs      x86_64 3.7.16-1.amzn2.0.4         amzn2-core           9.8 M
#  python38-devel    x86_64 3.8.16-1.amzn2.0.5         amzn2extra-python3.8 264 k
#  python38-libs     x86_64 3.8.16-1.amzn2.0.5         amzn2extra-python3.8  10 M
#  runc              x86_64 1.1.7-3.amzn2              amzn2extra-docker    3.0 M
#  sudo              x86_64 1.8.23-10.amzn2.3.4        amzn2-core           847 k
#  tensorflow-model-server-neuronx
#                    x86_64 2.10.1.2.10.1.0-0          neuron                68 M
# Removing:
#  kernel-devel      x86_64 5.10.184-175.731.amzn2     @amzn2extra-kernel-5.10
#                                                                            77 M
#
# Transaction Summary
# ================================================================================
# Install   2 Packages
# Upgrade  73 Packages
# Remove    1 Package
#
# Total download size: 369 M
# Downloading packages:
# Delta RPMs disabled because /usr/bin/applydeltarpm not installed.
# (1/75): amazon-ssm-agent-3.2.1377.0-1.amzn2.x86_64.rpm     |  24 MB   00:00
# (2/75): bind-export-libs-9.11.4-26.P2.amzn2.13.4.x86_64.rp | 1.1 MB   00:00
# (3/75): bind-libs-9.11.4-26.P2.amzn2.13.4.x86_64.rpm       | 159 kB   00:00
# (4/75): bind-libs-lite-9.11.4-26.P2.amzn2.13.4.x86_64.rpm  | 1.1 MB   00:00
# (5/75): bind-license-9.11.4-26.P2.amzn2.13.4.noarch.rpm    |  92 kB   00:00
# (6/75): bind-utils-9.11.4-26.P2.amzn2.13.4.x86_64.rpm      | 261 kB   00:00
# (7/75): ca-certificates-2021.2.50-72.amzn2.0.8.noarch.rpm  | 367 kB   00:00
# (8/75): cpp-7.3.1-17.amzn2.x86_64.rpm                      | 9.2 MB   00:00
# (9/75): cpp10-10.5.0-1.amzn2.0.2.x86_64.rpm                | 9.5 MB   00:00
# (10/75): amazon-cloudwatch-agent-1.300026.3-2.amzn2.x86_64 |  67 MB   00:00
# (11/75): cups-libs-1.6.3-51.amzn2.0.3.x86_64.rpm           | 356 kB   00:00
# (12/75): containerd-1.6.19-1.amzn2.0.3.x86_64.rpm          |  28 MB   00:00
# (13/75): curl-8.2.1-1.amzn2.0.3.x86_64.rpm                 | 369 kB   00:00
# (14/75): dhcp-common-4.2.5-79.amzn2.1.5.x86_64.rpm         | 177 kB   00:00
# (15/75): dhclient-4.2.5-79.amzn2.1.5.x86_64.rpm            | 287 kB   00:00
# (16/75): dhcp-libs-4.2.5-79.amzn2.1.5.x86_64.rpm           | 132 kB   00:00
# (17/75): ec2-hibinit-agent-1.0.2-5.amzn2.noarch.rpm        |  15 kB   00:00
# (18/75): gcc-c++-7.3.1-17.amzn2.x86_64.rpm                 |  13 MB   00:00
# (19/75): gcc-7.3.1-17.amzn2.x86_64.rpm                     |  22 MB   00:00
# (20/75): gcc-gfortran-7.3.1-17.amzn2.x86_64.rpm            |  11 MB   00:00
# (21/75): glibc-2.26-63.amzn2.0.1.x86_64.rpm                | 3.3 MB   00:00
# (22/75): glibc-all-langpacks-2.26-63.amzn2.0.1.x86_64.rpm  | 7.0 MB   00:00
# (23/75): glibc-common-2.26-63.amzn2.0.1.x86_64.rpm         | 774 kB   00:00
# (24/75): glibc-devel-2.26-63.amzn2.0.1.x86_64.rpm          | 995 kB   00:00
# (25/75): glibc-headers-2.26-63.amzn2.0.1.x86_64.rpm        | 516 kB   00:00
# (26/75): glibc-locale-source-2.26-63.amzn2.0.1.x86_64.rpm  | 3.2 MB   00:00
# (27/75): glibc-minimal-langpack-2.26-63.amzn2.0.1.x86_64.r |  33 kB   00:00
# (28/75): hwloc-libs-1.11.8-4.amzn2.0.2.x86_64.rpm          | 1.6 MB   00:00
# (29/75): krb5-devel-1.15.1-55.amzn2.2.6.x86_64.rpm         | 274 kB   00:00
# (30/75): krb5-libs-1.15.1-55.amzn2.2.6.x86_64.rpm          | 803 kB   00:00
# (31/75): libatomic-7.3.1-17.amzn2.x86_64.rpm               |  46 kB   00:00
# (32/75): kernel-headers-5.10.192-183.736.amzn2.x86_64.rpm  | 1.4 MB   00:00
# (33/75): gcc10-10.5.0-1.amzn2.0.2.x86_64.rpm               |  38 MB   00:00
# (34/75): libcilkrts-7.3.1-17.amzn2.x86_64.rpm              |  85 kB   00:00
# (35/75): libcrypt-2.26-63.amzn2.0.1.x86_64.rpm             |  53 kB   00:00
# (36/75): libcurl-8.2.1-1.amzn2.0.3.x86_64.rpm              | 333 kB   00:00
# (37/75): libgcc-7.3.1-17.amzn2.x86_64.rpm                  |  99 kB   00:00
# (38/75): kernel-devel-5.10.192-183.736.amzn2.x86_64.rpm    |  16 MB   00:00
# (39/75): libgfortran-7.3.1-17.amzn2.x86_64.rpm             | 536 kB   00:00
# (40/75): libcurl-devel-8.2.1-1.amzn2.0.3.x86_64.rpm        | 931 kB   00:00
# (41/75): libgomp-7.3.1-17.amzn2.x86_64.rpm                 | 205 kB   00:00
# (42/75): libidn-1.28-4.amzn2.0.5.x86_64.rpm                | 209 kB   00:00
# (43/75): libidn2-2.3.0-1.amzn2.0.3.x86_64.rpm              | 140 kB   00:00
# (44/75): libitm-7.3.1-17.amzn2.x86_64.rpm                  |  85 kB   00:00
# (45/75): libgs-9.25-5.amzn2.0.4.x86_64.rpm                 | 4.5 MB   00:00
# (46/75): libjpeg-turbo-2.0.90-2.amzn2.0.5.x86_64.rpm       | 171 kB   00:00
# (47/75): libjpeg-turbo-devel-2.0.90-2.amzn2.0.5.x86_64.rpm | 110 kB   00:00
# (48/75): libmpx-7.3.1-17.amzn2.x86_64.rpm                  |  52 kB   00:00
# (49/75): libkadm5-1.15.1-55.amzn2.2.6.x86_64.rpm           | 181 kB   00:00
# (50/75): libpng-1.5.13-8.amzn2.0.5.x86_64.rpm              | 212 kB   00:00
# (51/75): libnghttp2-1.41.0-1.amzn2.0.3.x86_64.rpm          |  72 kB   00:00
# (52/75): libsanitizer-7.3.1-17.amzn2.x86_64.rpm            | 642 kB   00:00
# (53/75): libquadmath-7.3.1-17.amzn2.x86_64.rpm             | 189 kB   00:00
# (54/75): libssh2-1.4.3-12.amzn2.2.5.x86_64.rpm             | 136 kB   00:00
# (55/75): libtasn1-4.10-1.amzn2.0.6.x86_64.rpm              | 320 kB   00:00
# (56/75): libstdc++-7.3.1-17.amzn2.x86_64.rpm               | 446 kB   00:00
# (57/75): libtiff-4.0.3-35.amzn2.0.12.x86_64.rpm            | 175 kB   00:00
# (58/75): libxml2-devel-2.9.1-6.amzn2.5.12.x86_64.rpm       | 1.1 MB   00:00
# (59/75): libxml2-2.9.1-6.amzn2.5.12.x86_64.rpm             | 661 kB   00:00
# (60/75): libxml2-python-2.9.1-6.amzn2.5.12.x86_64.rpm      | 247 kB   00:00
# (61/75): oniguruma-5.9.6-1.amzn2.0.5.x86_64.rpm            | 127 kB   00:00
# (62/75): openssh-7.4p1-22.amzn2.0.5.x86_64.rpm             | 508 kB   00:00
# (63/75): openssh-clients-7.4p1-22.amzn2.0.5.x86_64.rpm     | 652 kB   00:00
# (64/75): openssh-server-7.4p1-22.amzn2.0.5.x86_64.rpm      | 458 kB   00:00
# (65/75): openssl-1.0.2k-24.amzn2.0.9.x86_64.rpm            | 497 kB   00:00
# (66/75): openssl-libs-1.0.2k-24.amzn2.0.9.x86_64.rpm       | 1.2 MB   00:00
# (67/75): openssl-devel-1.0.2k-24.amzn2.0.9.x86_64.rpm      | 1.5 MB   00:00
# (68/75): python3-3.7.16-1.amzn2.0.4.x86_64.rpm             |  72 kB   00:00
# (69/75): python38-3.8.16-1.amzn2.0.5.x86_64.rpm            |  70 kB   00:00
# (70/75): python3-libs-3.7.16-1.amzn2.0.4.x86_64.rpm        | 9.8 MB   00:00
# (71/75): python38-devel-3.8.16-1.amzn2.0.5.x86_64.rpm      | 264 kB   00:00
# (72/75): sudo-1.8.23-10.amzn2.3.4.x86_64.rpm               | 847 kB   00:00
# (73/75): python38-libs-3.8.16-1.amzn2.0.5.x86_64.rpm       |  10 MB   00:00
# (74/75): runc-1.1.7-3.amzn2.x86_64.rpm                     | 3.0 MB   00:00
# (75/75): tensorflow-model-server-neuronx_2.10.1.2.10.1.0-x |  68 MB   00:00
# --------------------------------------------------------------------------------
# Total                                              118 MB/s | 369 MB  00:03
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Updating   : glibc-minimal-langpack-2.26-63.amzn2.0.1.x86_64            1/150
#   Updating   : glibc-2.26-63.amzn2.0.1.x86_64                             2/150
#   Updating   : glibc-common-2.26-63.amzn2.0.1.x86_64                      3/150
#   Updating   : libgcc-7.3.1-17.amzn2.x86_64                               4/150
#   Updating   : libcrypt-2.26-63.amzn2.0.1.x86_64                          5/150
#   Updating   : libstdc++-7.3.1-17.amzn2.x86_64                            6/150
#   Updating   : libxml2-2.9.1-6.amzn2.5.12.x86_64                          7/150
#   Updating   : libjpeg-turbo-2.0.90-2.amzn2.0.5.x86_64                    8/150
#   Updating   : libidn-1.28-4.amzn2.0.5.x86_64                             9/150
#   Updating   : libquadmath-7.3.1-17.amzn2.x86_64                         10/150
#   Updating   : 12:dhcp-libs-4.2.5-79.amzn2.1.5.x86_64                    11/150
#   Updating   : libnghttp2-1.41.0-1.amzn2.0.3.x86_64                      12/150
#   Updating   : libgomp-7.3.1-17.amzn2.x86_64                             13/150
#   Updating   : libidn2-2.3.0-1.amzn2.0.3.x86_64                          14/150
#   Updating   : 32:bind-license-9.11.4-26.P2.amzn2.13.4.noarch            15/150
#   Updating   : 12:dhcp-common-4.2.5-79.amzn2.1.5.x86_64                  16/150
#   Updating   : libgfortran-7.3.1-17.amzn2.x86_64                         17/150
#   Updating   : libtiff-4.0.3-35.amzn2.0.12.x86_64                        18/150
#   Updating   : libcilkrts-7.3.1-17.amzn2.x86_64                          19/150
#   Updating   : libsanitizer-7.3.1-17.amzn2.x86_64                        20/150
#   Updating   : libitm-7.3.1-17.amzn2.x86_64                              21/150
#   Updating   : 2:libpng-1.5.13-8.amzn2.0.5.x86_64                        22/150
#   Updating   : cpp10-10.5.0-1.amzn2.0.2.x86_64                           23/150
#   Updating   : cpp-7.3.1-17.amzn2.x86_64                                 24/150
#   Updating   : libmpx-7.3.1-17.amzn2.x86_64                              25/150
#   Updating   : runc-1.1.7-3.amzn2.x86_64                                 26/150
#   Updating   : libatomic-7.3.1-17.amzn2.x86_64                           27/150
#   Updating   : ca-certificates-2021.2.50-72.amzn2.0.8.noarch             28/150
#   Updating   : 1:openssl-libs-1.0.2k-24.amzn2.0.9.x86_64                 29/150
#   Updating   : krb5-libs-1.15.1-55.amzn2.2.6.x86_64                      30/150
#   Updating   : 32:bind-libs-lite-9.11.4-26.P2.amzn2.13.4.x86_64          31/150
#   Updating   : python38-libs-3.8.16-1.amzn2.0.5.x86_64                   32/150
#   Installing : python38-3.8.16-1.amzn2.0.5.x86_64                        33/150
#   Updating   : openssh-7.4p1-22.amzn2.0.5.x86_64                         34/150
#   Updating   : libssh2-1.4.3-12.amzn2.2.5.x86_64                         35/150
#   Updating   : libcurl-8.2.1-1.amzn2.0.3.x86_64                          36/150
#   Updating   : 32:bind-libs-9.11.4-26.P2.amzn2.13.4.x86_64               37/150
#   Updating   : 32:bind-export-libs-9.11.4-26.P2.amzn2.13.4.x86_64        38/150
#   Updating   : 1:cups-libs-1.6.3-51.amzn2.0.3.x86_64                     39/150
#   Updating   : libkadm5-1.15.1-55.amzn2.2.6.x86_64                       40/150
#   Updating   : krb5-devel-1.15.1-55.amzn2.2.6.x86_64                     41/150
#   Updating   : python3-libs-3.7.16-1.amzn2.0.4.x86_64                    42/150
#   Updating   : python3-3.7.16-1.amzn2.0.4.x86_64                         43/150
#   Updating   : kernel-headers-5.10.192-183.736.amzn2.x86_64              44/150
#   Updating   : glibc-headers-2.26-63.amzn2.0.1.x86_64                    45/150
#   Updating   : glibc-devel-2.26-63.amzn2.0.1.x86_64                      46/150
#   Updating   : gcc10-10.5.0-1.amzn2.0.2.x86_64                           47/150
#   Updating   : gcc-7.3.1-17.amzn2.x86_64                                 48/150
#   Updating   : gcc-c++-7.3.1-17.amzn2.x86_64                             49/150
#   Updating   : gcc-gfortran-7.3.1-17.amzn2.x86_64                        50/150
#   Installing : kernel-devel-5.10.192-183.736.amzn2.x86_64                51/150
#   Updating   : 1:openssl-devel-1.0.2k-24.amzn2.0.9.x86_64                52/150
#   Updating   : libgs-9.25-5.amzn2.0.4.x86_64                             53/150
#   Updating   : 12:dhclient-4.2.5-79.amzn2.1.5.x86_64                     54/150
#   Updating   : 32:bind-utils-9.11.4-26.P2.amzn2.13.4.x86_64              55/150
#   Updating   : libcurl-devel-8.2.1-1.amzn2.0.3.x86_64                    56/150
#   Updating   : curl-8.2.1-1.amzn2.0.3.x86_64                             57/150
#   Updating   : openssh-server-7.4p1-22.amzn2.0.5.x86_64                  58/150
#   Updating   : openssh-clients-7.4p1-22.amzn2.0.5.x86_64                 59/150
#   Updating   : python38-devel-3.8.16-1.amzn2.0.5.x86_64                  60/150
#   Updating   : 1:openssl-1.0.2k-24.amzn2.0.9.x86_64                      61/150
#   Updating   : containerd-1.6.19-1.amzn2.0.3.x86_64                      62/150
#   Updating   : libjpeg-turbo-devel-2.0.90-2.amzn2.0.5.x86_64             63/150
#   Updating   : libxml2-python-2.9.1-6.amzn2.5.12.x86_64                  64/150
#   Updating   : libxml2-devel-2.9.1-6.amzn2.5.12.x86_64                   65/150
#   Updating   : tensorflow-model-server-neuronx-2.10.1.2.10.1.0-0.x86_    66/150
#   Updating   : glibc-all-langpacks-2.26-63.amzn2.0.1.x86_64              67/150
#   Updating   : glibc-locale-source-2.26-63.amzn2.0.1.x86_64              68/150
#   Updating   : oniguruma-5.9.6-1.amzn2.0.5.x86_64                        69/150
#   Updating   : hwloc-libs-1.11.8-4.amzn2.0.2.x86_64                      70/150
#   Updating   : libtasn1-4.10-1.amzn2.0.6.x86_64                          71/150
#   Updating   : sudo-1.8.23-10.amzn2.3.4.x86_64                           72/150
#   Updating   : amazon-ssm-agent-3.2.1377.0-1.amzn2.x86_64                73/150
# amazon-cloudwatch-agent is running
#
# ****** processing amazon-cloudwatch-agent ******
#   Updating   : amazon-cloudwatch-agent-1.300026.3-2.amzn2.x86_64         74/150
#   Updating   : ec2-hibinit-agent-1.0.2-5.amzn2.noarch                    75/150
#   Cleanup    : 12:dhclient-4.2.5-79.amzn2.1.2.x86_64                     76/150
#   Cleanup    : 32:bind-utils-9.11.4-26.P2.amzn2.13.1.x86_64              77/150
#   Cleanup    : 32:bind-libs-9.11.4-26.P2.amzn2.13.1.x86_64               78/150
#   Cleanup    : libgs-9.25-5.amzn2.0.3.x86_64                             79/150
#   Cleanup    : curl-8.0.1-1.amzn2.0.1.x86_64                             80/150
#   Cleanup    : 1:cups-libs-1.6.3-51.amzn2.0.2.x86_64                     81/150
#   Cleanup    : 32:bind-libs-lite-9.11.4-26.P2.amzn2.13.1.x86_64          82/150
#   Cleanup    : python3-3.7.16-1.amzn2.0.2.x86_64                         83/150
#   Cleanup    : python3-libs-3.7.16-1.amzn2.0.2.x86_64                    84/150
#   Cleanup    : openssh-clients-7.4p1-22.amzn2.0.3.x86_64                 85/150
#   Cleanup    : openssh-server-7.4p1-22.amzn2.0.3.x86_64                  86/150
#   Cleanup    : libtiff-4.0.3-35.amzn2.0.8.x86_64                         87/150
#   Cleanup    : 1:openssl-1.0.2k-24.amzn2.0.7.x86_64                      88/150
#   Cleanup    : python38-devel-3.8.16-1.amzn2.0.2.x86_64                  89/150
#   Cleanup    : glibc-locale-source-2.26-63.amzn2.x86_64                  90/150
#   Cleanup    : glibc-all-langpacks-2.26-63.amzn2.x86_64                  91/150
#   Cleanup    : 1:openssl-devel-1.0.2k-24.amzn2.0.7.x86_64                92/150
#   Cleanup    : 12:dhcp-common-4.2.5-79.amzn2.1.2.x86_64                  93/150
#   Cleanup    : 12:dhcp-libs-4.2.5-79.amzn2.1.2.x86_64                    94/150
#   Cleanup    : libxml2-devel-2.9.1-6.amzn2.5.8.x86_64                    95/150
#   Cleanup    : kernel-devel-5.10.184-175.731.amzn2.x86_64                96/150
#   Cleanup    : libjpeg-turbo-devel-2.0.90-2.amzn2.0.1.x86_64             97/150
#   Cleanup    : libcurl-devel-8.0.1-1.amzn2.0.1.x86_64                    98/150
#   Cleanup    : 32:bind-license-9.11.4-26.P2.amzn2.13.1.noarch            99/150
#   Cleanup    : amazon-cloudwatch-agent-1.300025.0-1.amzn2.x86_64        100/150
#   Cleanup    : ec2-hibinit-agent-1.0.2-4.amzn2.noarch                   101/150
#   Cleanup    : libcurl-8.0.1-1.amzn2.0.1.x86_64                         102/150
#   Cleanup    : python38-3.8.16-1.amzn2.0.2.x86_64                       103/150
#   Cleanup    : python38-libs-3.8.16-1.amzn2.0.2.x86_64                  104/150
#   Cleanup    : krb5-devel-1.15.1-55.amzn2.2.5.x86_64                    105/150
#   Cleanup    : libkadm5-1.15.1-55.amzn2.2.5.x86_64                      106/150
#   Cleanup    : tensorflow-model-server-neuronx-2.10.1.2.9.3.0-0.x86_6   107/150
#   Cleanup    : openssh-7.4p1-22.amzn2.0.3.x86_64                        108/150
#   Cleanup    : 32:bind-export-libs-9.11.4-26.P2.amzn2.13.1.x86_64       109/150
#   Cleanup    : gcc-gfortran-7.3.1-15.amzn2.x86_64                       110/150
#   Cleanup    : libgfortran-7.3.1-15.amzn2.x86_64                        111/150
#   Cleanup    : gcc-c++-7.3.1-15.amzn2.x86_64                            112/150
#   Cleanup    : gcc-7.3.1-15.amzn2.x86_64                                113/150
#   Cleanup    : gcc10-10.4.0-1.amzn2.0.1.x86_64                          114/150
#   Cleanup    : glibc-devel-2.26-63.amzn2.x86_64                         115/150
#   Cleanup    : libcilkrts-7.3.1-15.amzn2.x86_64                         116/150
#   Cleanup    : libsanitizer-7.3.1-15.amzn2.x86_64                       117/150
#   Cleanup    : libstdc++-7.3.1-15.amzn2.x86_64                          118/150
#   Cleanup    : libssh2-1.4.3-12.amzn2.2.4.x86_64                        119/150
#   Cleanup    : 1:openssl-libs-1.0.2k-24.amzn2.0.7.x86_64                120/150
#   Cleanup    : krb5-libs-1.15.1-55.amzn2.2.5.x86_64                     121/150
#   Cleanup    : libxml2-python-2.9.1-6.amzn2.5.8.x86_64                  122/150
#   Cleanup    : glibc-headers-2.26-63.amzn2.x86_64                       123/150
#   Cleanup    : containerd-1.6.19-1.amzn2.0.1.x86_64                     124/150
#   Cleanup    : runc-1.1.7-1.amzn2.x86_64                                125/150
#   Cleanup    : libxml2-2.9.1-6.amzn2.5.8.x86_64                         126/150
#   Cleanup    : libgcc-7.3.1-15.amzn2.x86_64                             127/150
#   Cleanup    : libcrypt-2.26-63.amzn2.x86_64                            128/150
#   Cleanup    : cpp10-10.4.0-1.amzn2.0.1.x86_64                          129/150
#   Cleanup    : libgomp-7.3.1-15.amzn2.x86_64                            130/150
#   Cleanup    : cpp-7.3.1-15.amzn2.x86_64                                131/150
#   Cleanup    : libatomic-7.3.1-15.amzn2.x86_64                          132/150
#   Cleanup    : libitm-7.3.1-15.amzn2.x86_64                             133/150
#   Cleanup    : libmpx-7.3.1-15.amzn2.x86_64                             134/150
#   Cleanup    : libquadmath-7.3.1-15.amzn2.x86_64                        135/150
#   Cleanup    : libidn2-2.3.0-1.amzn2.x86_64                             136/150
#   Cleanup    : libnghttp2-1.41.0-1.amzn2.0.1.x86_64                     137/150
#   Cleanup    : libjpeg-turbo-2.0.90-2.amzn2.0.1.x86_64                  138/150
#   Cleanup    : libidn-1.28-4.amzn2.0.2.x86_64                           139/150
#   Cleanup    : 2:libpng-1.5.13-8.amzn2.0.1.x86_64                       140/150
#   Cleanup    : sudo-1.8.23-10.amzn2.3.1.x86_64                          141/150
#   Cleanup    : libtasn1-4.10-1.amzn2.0.3.x86_64                         142/150
#   Cleanup    : hwloc-libs-1.11.8-4.amzn2.x86_64                         143/150
#   Cleanup    : amazon-ssm-agent-3.2.815.0-1.x86_64                      144/150
#   Cleanup    : oniguruma-5.9.6-1.amzn2.0.4.x86_64                       145/150
#   Cleanup    : kernel-headers-5.10.186-179.751.amzn2.x86_64             146/150
#   Cleanup    : ca-certificates-2021.2.50-72.amzn2.0.7.noarch            147/150
#   Cleanup    : glibc-minimal-langpack-2.26-63.amzn2.x86_64              148/150
#   Cleanup    : glibc-2.26-63.amzn2.x86_64                               149/150
#   Cleanup    : glibc-common-2.26-63.amzn2.x86_64                        150/150
#
# ****** processing amazon-cloudwatch-agent ******
#   Verifying  : glibc-common-2.26-63.amzn2.0.1.x86_64                      1/150
#   Verifying  : libitm-7.3.1-17.amzn2.x86_64                               2/150
#   Verifying  : 12:dhclient-4.2.5-79.amzn2.1.5.x86_64                      3/150
#   Verifying  : 1:openssl-1.0.2k-24.amzn2.0.9.x86_64                       4/150
#   Verifying  : 12:dhcp-common-4.2.5-79.amzn2.1.5.x86_64                   5/150
#   Verifying  : ec2-hibinit-agent-1.0.2-5.amzn2.noarch                     6/150
#   Verifying  : libidn-1.28-4.amzn2.0.5.x86_64                             7/150
#   Verifying  : libgs-9.25-5.amzn2.0.4.x86_64                              8/150
#   Verifying  : libquadmath-7.3.1-17.amzn2.x86_64                          9/150
#   Verifying  : 32:bind-utils-9.11.4-26.P2.amzn2.13.4.x86_64              10/150
#   Verifying  : containerd-1.6.19-1.amzn2.0.3.x86_64                      11/150
#   Verifying  : amazon-cloudwatch-agent-1.300026.3-2.amzn2.x86_64         12/150
#   Verifying  : libxml2-2.9.1-6.amzn2.5.12.x86_64                         13/150
#   Verifying  : python38-libs-3.8.16-1.amzn2.0.5.x86_64                   14/150
#   Verifying  : python3-libs-3.7.16-1.amzn2.0.4.x86_64                    15/150
#   Verifying  : gcc-c++-7.3.1-17.amzn2.x86_64                             16/150
#   Verifying  : 1:openssl-devel-1.0.2k-24.amzn2.0.9.x86_64                17/150
#   Verifying  : python3-3.7.16-1.amzn2.0.4.x86_64                         18/150
#   Verifying  : python38-devel-3.8.16-1.amzn2.0.5.x86_64                  19/150
#   Verifying  : kernel-headers-5.10.192-183.736.amzn2.x86_64              20/150
#   Verifying  : glibc-all-langpacks-2.26-63.amzn2.0.1.x86_64              21/150
#   Verifying  : 2:libpng-1.5.13-8.amzn2.0.5.x86_64                        22/150
#   Verifying  : openssh-server-7.4p1-22.amzn2.0.5.x86_64                  23/150
#   Verifying  : kernel-devel-5.10.192-183.736.amzn2.x86_64                24/150
#   Verifying  : libcurl-devel-8.2.1-1.amzn2.0.3.x86_64                    25/150
#   Verifying  : libstdc++-7.3.1-17.amzn2.x86_64                           26/150
#   Verifying  : 1:openssl-libs-1.0.2k-24.amzn2.0.9.x86_64                 27/150
#   Verifying  : libgcc-7.3.1-17.amzn2.x86_64                              28/150
#   Verifying  : ca-certificates-2021.2.50-72.amzn2.0.8.noarch             29/150
#   Verifying  : python38-3.8.16-1.amzn2.0.5.x86_64                        30/150
#   Verifying  : glibc-minimal-langpack-2.26-63.amzn2.0.1.x86_64           31/150
#   Verifying  : 32:bind-export-libs-9.11.4-26.P2.amzn2.13.4.x86_64        32/150
#   Verifying  : openssh-7.4p1-22.amzn2.0.5.x86_64                         33/150
#   Verifying  : libcilkrts-7.3.1-17.amzn2.x86_64                          34/150
#   Verifying  : krb5-devel-1.15.1-55.amzn2.2.6.x86_64                     35/150
#   Verifying  : cpp10-10.5.0-1.amzn2.0.2.x86_64                           36/150
#   Verifying  : libgfortran-7.3.1-17.amzn2.x86_64                         37/150
#   Verifying  : krb5-libs-1.15.1-55.amzn2.2.6.x86_64                      38/150
#   Verifying  : gcc10-10.5.0-1.amzn2.0.2.x86_64                           39/150
#   Verifying  : 32:bind-license-9.11.4-26.P2.amzn2.13.4.noarch            40/150
#   Verifying  : oniguruma-5.9.6-1.amzn2.0.5.x86_64                        41/150
#   Verifying  : libtiff-4.0.3-35.amzn2.0.12.x86_64                        42/150
#   Verifying  : 12:dhcp-libs-4.2.5-79.amzn2.1.5.x86_64                    43/150
#   Verifying  : libssh2-1.4.3-12.amzn2.2.5.x86_64                         44/150
#   Verifying  : libjpeg-turbo-devel-2.0.90-2.amzn2.0.5.x86_64             45/150
#   Verifying  : libcurl-8.2.1-1.amzn2.0.3.x86_64                          46/150
#   Verifying  : tensorflow-model-server-neuronx-2.10.1.2.10.1.0-0.x86_    47/150
#   Verifying  : cpp-7.3.1-17.amzn2.x86_64                                 48/150
#   Verifying  : gcc-gfortran-7.3.1-17.amzn2.x86_64                        49/150
#   Verifying  : gcc-7.3.1-17.amzn2.x86_64                                 50/150
#   Verifying  : libcrypt-2.26-63.amzn2.0.1.x86_64                         51/150
#   Verifying  : amazon-ssm-agent-3.2.1377.0-1.amzn2.x86_64                52/150
#   Verifying  : libmpx-7.3.1-17.amzn2.x86_64                              53/150
#   Verifying  : hwloc-libs-1.11.8-4.amzn2.0.2.x86_64                      54/150
#   Verifying  : openssh-clients-7.4p1-22.amzn2.0.5.x86_64                 55/150
#   Verifying  : runc-1.1.7-3.amzn2.x86_64                                 56/150
#   Verifying  : glibc-devel-2.26-63.amzn2.0.1.x86_64                      57/150
#   Verifying  : libtasn1-4.10-1.amzn2.0.6.x86_64                          58/150
#   Verifying  : sudo-1.8.23-10.amzn2.3.4.x86_64                           59/150
#   Verifying  : 32:bind-libs-lite-9.11.4-26.P2.amzn2.13.4.x86_64          60/150
#   Verifying  : libsanitizer-7.3.1-17.amzn2.x86_64                        61/150
#   Verifying  : glibc-headers-2.26-63.amzn2.0.1.x86_64                    62/150
#   Verifying  : libjpeg-turbo-2.0.90-2.amzn2.0.5.x86_64                   63/150
#   Verifying  : libxml2-python-2.9.1-6.amzn2.5.12.x86_64                  64/150
#   Verifying  : libatomic-7.3.1-17.amzn2.x86_64                           65/150
#   Verifying  : glibc-2.26-63.amzn2.0.1.x86_64                            66/150
#   Verifying  : 32:bind-libs-9.11.4-26.P2.amzn2.13.4.x86_64               67/150
#   Verifying  : libnghttp2-1.41.0-1.amzn2.0.3.x86_64                      68/150
#   Verifying  : 1:cups-libs-1.6.3-51.amzn2.0.3.x86_64                     69/150
#   Verifying  : glibc-locale-source-2.26-63.amzn2.0.1.x86_64              70/150
#   Verifying  : libkadm5-1.15.1-55.amzn2.2.6.x86_64                       71/150
#   Verifying  : libxml2-devel-2.9.1-6.amzn2.5.12.x86_64                   72/150
#   Verifying  : libgomp-7.3.1-17.amzn2.x86_64                             73/150
#   Verifying  : curl-8.2.1-1.amzn2.0.3.x86_64                             74/150
#   Verifying  : libidn2-2.3.0-1.amzn2.0.3.x86_64                          75/150
#   Verifying  : 32:bind-license-9.11.4-26.P2.amzn2.13.1.noarch            76/150
#   Verifying  : libjpeg-turbo-devel-2.0.90-2.amzn2.0.1.x86_64             77/150
#   Verifying  : libidn-1.28-4.amzn2.0.2.x86_64                            78/150
#   Verifying  : glibc-all-langpacks-2.26-63.amzn2.x86_64                  79/150
#   Verifying  : python38-3.8.16-1.amzn2.0.2.x86_64                        80/150
#   Verifying  : krb5-libs-1.15.1-55.amzn2.2.5.x86_64                      81/150
#   Verifying  : libxml2-2.9.1-6.amzn2.5.8.x86_64                          82/150
#   Verifying  : libtiff-4.0.3-35.amzn2.0.8.x86_64                         83/150
#   Verifying  : libsanitizer-7.3.1-15.amzn2.x86_64                        84/150
#   Verifying  : libidn2-2.3.0-1.amzn2.x86_64                              85/150
#   Verifying  : python38-libs-3.8.16-1.amzn2.0.2.x86_64                   86/150
#   Verifying  : libatomic-7.3.1-15.amzn2.x86_64                           87/150
#   Verifying  : 12:dhcp-common-4.2.5-79.amzn2.1.2.x86_64                  88/150
#   Verifying  : runc-1.1.7-1.amzn2.x86_64                                 89/150
#   Verifying  : libcilkrts-7.3.1-15.amzn2.x86_64                          90/150
#   Verifying  : gcc10-10.4.0-1.amzn2.0.1.x86_64                           91/150
#   Verifying  : 12:dhclient-4.2.5-79.amzn2.1.2.x86_64                     92/150
#   Verifying  : glibc-headers-2.26-63.amzn2.x86_64                        93/150
#   Verifying  : 32:bind-libs-9.11.4-26.P2.amzn2.13.1.x86_64               94/150
#   Verifying  : sudo-1.8.23-10.amzn2.3.1.x86_64                           95/150
#   Verifying  : glibc-devel-2.26-63.amzn2.x86_64                          96/150
#   Verifying  : glibc-locale-source-2.26-63.amzn2.x86_64                  97/150
#   Verifying  : amazon-cloudwatch-agent-1.300025.0-1.amzn2.x86_64         98/150
#   Verifying  : 32:bind-utils-9.11.4-26.P2.amzn2.13.1.x86_64              99/150
#   Verifying  : 32:bind-libs-lite-9.11.4-26.P2.amzn2.13.1.x86_64         100/150
#   Verifying  : oniguruma-5.9.6-1.amzn2.0.4.x86_64                       101/150
#   Verifying  : amazon-ssm-agent-3.2.815.0-1.x86_64                      102/150
#   Verifying  : libjpeg-turbo-2.0.90-2.amzn2.0.1.x86_64                  103/150
#   Verifying  : openssh-clients-7.4p1-22.amzn2.0.3.x86_64                104/150
#   Verifying  : libtasn1-4.10-1.amzn2.0.3.x86_64                         105/150
#   Verifying  : python38-devel-3.8.16-1.amzn2.0.2.x86_64                 106/150
#   Verifying  : libcrypt-2.26-63.amzn2.x86_64                            107/150
#   Verifying  : cpp10-10.4.0-1.amzn2.0.1.x86_64                          108/150
#   Verifying  : ca-certificates-2021.2.50-72.amzn2.0.7.noarch            109/150
#   Verifying  : gcc-gfortran-7.3.1-15.amzn2.x86_64                       110/150
#   Verifying  : openssh-server-7.4p1-22.amzn2.0.3.x86_64                 111/150
#   Verifying  : 1:openssl-devel-1.0.2k-24.amzn2.0.7.x86_64               112/150
#   Verifying  : libcurl-devel-8.0.1-1.amzn2.0.1.x86_64                   113/150
#   Verifying  : 1:openssl-1.0.2k-24.amzn2.0.7.x86_64                     114/150
#   Verifying  : libxml2-python-2.9.1-6.amzn2.5.8.x86_64                  115/150
#   Verifying  : 12:dhcp-libs-4.2.5-79.amzn2.1.2.x86_64                   116/150
#   Verifying  : tensorflow-model-server-neuronx-2.10.1.2.9.3.0-0.x86_6   117/150
#   Verifying  : libstdc++-7.3.1-15.amzn2.x86_64                          118/150
#   Verifying  : libgfortran-7.3.1-15.amzn2.x86_64                        119/150
#   Verifying  : kernel-devel-5.10.184-175.731.amzn2.x86_64               120/150
#   Verifying  : glibc-2.26-63.amzn2.x86_64                               121/150
#   Verifying  : kernel-headers-5.10.186-179.751.amzn2.x86_64             122/150
# ...
#   ca-certificates.noarch 0:2021.2.50-72.amzn2.0.8
#   containerd.x86_64 0:1.6.19-1.amzn2.0.3
#   cpp.x86_64 0:7.3.1-17.amzn2
#   cpp10.x86_64 0:10.5.0-1.amzn2.0.2
#   cups-libs.x86_64 1:1.6.3-51.amzn2.0.3
#   curl.x86_64 0:8.2.1-1.amzn2.0.3
#   dhclient.x86_64 12:4.2.5-79.amzn2.1.5
#   dhcp-common.x86_64 12:4.2.5-79.amzn2.1.5
#   dhcp-libs.x86_64 12:4.2.5-79.amzn2.1.5
#   ec2-hibinit-agent.noarch 0:1.0.2-5.amzn2
#   gcc.x86_64 0:7.3.1-17.amzn2
#   gcc-c++.x86_64 0:7.3.1-17.amzn2
#   gcc-gfortran.x86_64 0:7.3.1-17.amzn2
#   gcc10.x86_64 0:10.5.0-1.amzn2.0.2
#   glibc.x86_64 0:2.26-63.amzn2.0.1
#   glibc-all-langpacks.x86_64 0:2.26-63.amzn2.0.1
#   glibc-common.x86_64 0:2.26-63.amzn2.0.1
#   glibc-devel.x86_64 0:2.26-63.amzn2.0.1
#   glibc-headers.x86_64 0:2.26-63.amzn2.0.1
#   glibc-locale-source.x86_64 0:2.26-63.amzn2.0.1
#   glibc-minimal-langpack.x86_64 0:2.26-63.amzn2.0.1
#   hwloc-libs.x86_64 0:1.11.8-4.amzn2.0.2
#   kernel-headers.x86_64 0:5.10.192-183.736.amzn2
#   krb5-devel.x86_64 0:1.15.1-55.amzn2.2.6
#   krb5-libs.x86_64 0:1.15.1-55.amzn2.2.6
#   libatomic.x86_64 0:7.3.1-17.amzn2
#   libcilkrts.x86_64 0:7.3.1-17.amzn2
#   libcrypt.x86_64 0:2.26-63.amzn2.0.1
#   libcurl.x86_64 0:8.2.1-1.amzn2.0.3
#   libcurl-devel.x86_64 0:8.2.1-1.amzn2.0.3
#   libgcc.x86_64 0:7.3.1-17.amzn2
#   libgfortran.x86_64 0:7.3.1-17.amzn2
#   libgomp.x86_64 0:7.3.1-17.amzn2
#   libgs.x86_64 0:9.25-5.amzn2.0.4
#   libidn.x86_64 0:1.28-4.amzn2.0.5
#   libidn2.x86_64 0:2.3.0-1.amzn2.0.3
#   libitm.x86_64 0:7.3.1-17.amzn2
#   libjpeg-turbo.x86_64 0:2.0.90-2.amzn2.0.5
#   libjpeg-turbo-devel.x86_64 0:2.0.90-2.amzn2.0.5
#   libkadm5.x86_64 0:1.15.1-55.amzn2.2.6
#   libmpx.x86_64 0:7.3.1-17.amzn2
#   libnghttp2.x86_64 0:1.41.0-1.amzn2.0.3
#   libpng.x86_64 2:1.5.13-8.amzn2.0.5
#   libquadmath.x86_64 0:7.3.1-17.amzn2
#   libsanitizer.x86_64 0:7.3.1-17.amzn2
#   libssh2.x86_64 0:1.4.3-12.amzn2.2.5
#   libstdc++.x86_64 0:7.3.1-17.amzn2
#   libtasn1.x86_64 0:4.10-1.amzn2.0.6
#   libtiff.x86_64 0:4.0.3-35.amzn2.0.12
#   libxml2.x86_64 0:2.9.1-6.amzn2.5.12
#   libxml2-devel.x86_64 0:2.9.1-6.amzn2.5.12
#   libxml2-python.x86_64 0:2.9.1-6.amzn2.5.12
#   oniguruma.x86_64 0:5.9.6-1.amzn2.0.5
#   openssh.x86_64 0:7.4p1-22.amzn2.0.5
#   openssh-clients.x86_64 0:7.4p1-22.amzn2.0.5
#   openssh-server.x86_64 0:7.4p1-22.amzn2.0.5
#   openssl.x86_64 1:1.0.2k-24.amzn2.0.9
#   openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.9
#   openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.9
#   python3.x86_64 0:3.7.16-1.amzn2.0.4
#   python3-libs.x86_64 0:3.7.16-1.amzn2.0.4
#   python38-devel.x86_64 0:3.8.16-1.amzn2.0.5
#   python38-libs.x86_64 0:3.8.16-1.amzn2.0.5
#   runc.x86_64 0:1.1.7-3.amzn2
#   sudo.x86_64 0:1.8.23-10.amzn2.3.4
#   tensorflow-model-server-neuronx.x86_64 0:2.10.1.2.10.1.0-0
#
# Replaced:
#   python38.x86_64 0:3.8.16-1.amzn2.0.2
#
# Complete!
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# Existing lock /var/run/yum.pid: another copy is running as pid 4901.
# Another app is currently holding the yum lock; waiting for it to exit...
#   The other application is: yum
#     Memory :  81 M RSS (299 MB VSZ)
#     Started: Fri Sep 15 15:26:51 2023 - 00:01 ago
#     State  : Running, pid: 4901
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-epel                                          | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# epel/x86_64/metalink                                     |  25 kB     00:00
# github_git-lfs/x86_64/signature                          |  819 B     00:00
# github_git-lfs/x86_64/signature                          |  951 B     00:00 !!!
# github_git-lfs-source/signature                          |  819 B     00:00
# github_git-lfs-source/signature                          |  951 B     00:00 !!!
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# 286 packages excluded due to repository priority protections
# Package amazon-linux-extras-2.0.1-1.amzn2.noarch already installed and latest version
# Nothing to do
# Installing epel-release
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# Cleaning repos: amzn2-core amzn2extra-docker amzn2extra-epel
#               : amzn2extra-kernel-5.10 amzn2extra-python3.8 centos-extras
#               : copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap
#               : docker-ce-stable epel github_git-lfs github_git-lfs-source
#               : libnvidia-container neuron
# 54 metadata files removed
# 21 sqlite files removed
# 0 metadata files removed
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-epel                                          | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# epel/x86_64/metalink                                     |  25 kB     00:00
# epel                                                     | 4.7 kB     00:00
# github_git-lfs/x86_64/signature                          |  819 B     00:00
# github_git-lfs/x86_64/signature                          |  951 B     00:00 !!!
# github_git-lfs-source/signature                          |  819 B     00:00
# github_git-lfs-source/signature                          |  951 B     00:00 !!!
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# (1/18): amzn2-core/2/x86_64/updateinfo                     | 695 kB   00:00
# (2/18): amzn2-core/2/x86_64/group_gz                       | 2.5 kB   00:00
# (3/18): amzn2extra-epel/2/x86_64/primary_db                | 1.8 kB   00:00
# (4/18): amzn2extra-kernel-5.10/2/x86_64/updateinfo         |  37 kB   00:00
# (5/18): amzn2extra-docker/2/x86_64/updateinfo              |  13 kB   00:00
# (6/18): amzn2extra-docker/2/x86_64/primary_db              | 111 kB   00:00
# (7/18): amzn2extra-python3.8/2/x86_64/updateinfo           |   76 B   00:00
# (8/18): amzn2extra-epel/2/x86_64/updateinfo                |   76 B   00:00
# (9/18): amzn2extra-python3.8/2/x86_64/primary_db           |  72 kB   00:00
# (10/18): copr:copr.fedorainfracloud.org:vbatts:shadow-util | 6.1 kB   00:00
# (11/18): epel/x86_64/group_gz                              |  99 kB   00:00
# (12/18): epel/x86_64/updateinfo                            | 1.0 MB   00:00
# (13/18): amzn2extra-kernel-5.10/2/x86_64/primary_db        |  22 MB   00:00
# (14/18): epel/x86_64/primary_db                            | 7.0 MB   00:00
# (15/18): centos-extras/primary_db                          | 250 kB   00:00
# (16/18): libnvidia-container/x86_64/primary                |  32 kB   00:00
# (17/18): neuron/primary_db                                 | 145 kB   00:00
# (18/18): amzn2-core/2/x86_64/primary_db                    |  78 MB   00:01
# (1/2): github_git-lfs/x86_64/primary                       |  175 B   00:00
# (2/2): github_git-lfs-source/primary                       |  175 B   00:00
# libnvidia-container                                                     211/211
# 286 packages excluded due to repository priority protections
# Package epel-release-7-11.noarch already installed and latest version
# Nothing to do
#   0 †ansible2                 available    \
#         [ =2.4.2  =2.4.6  =2.8  =stable ]
#   2  httpd_modules            available    [ =1.0  =stable ]
#   3  memcached1.5             available    \
#         [ =1.5.1  =1.5.16  =1.5.17 ]
#   6 †postgresql10             available    [ =10  =stable ]
#   9  R3.4                     available    [ =3.4.3  =stable ]
#  10  rust1                    available    \
#         [ =1.22.1  =1.26.0  =1.26.1  =1.27.2  =1.31.0  =1.38.0
#           =stable ]
#  18  libreoffice              available    \
#         [ =5.0.6.2_15  =5.3.6.1  =stable ]
#  19  gimp                     available    [ =2.8.22 ]
#  20 †docker=latest            enabled      \
#         [ =17.12.1  =18.03.1  =18.06.1  =18.09.9  =stable ]
#  21  mate-desktop1.x          available    \
#         [ =1.19.0  =1.20.0  =stable ]
#  22  GraphicsMagick1.3        available    \
#         [ =1.3.29  =1.3.32  =1.3.34  =stable ]
#  23 †tomcat8.5                available    \
#         [ =8.5.31  =8.5.32  =8.5.38  =8.5.40  =8.5.42  =8.5.50
#           =stable ]
#  24  epel=latest              enabled      [ =7.11  =stable ]
#  25  testing                  available    [ =1.0  =stable ]
#  26  ecs                      available    [ =stable ]
#  27 †corretto8                available    \
#         [ =1.8.0_192  =1.8.0_202  =1.8.0_212  =1.8.0_222  =1.8.0_232
#           =1.8.0_242  =stable ]
#  30 †squid4                   available    [ =4  =stable ]
#  32  lustre2.10               available    \
#         [ =2.10.5  =2.10.8  =stable ]
#  33 †java-openjdk11           available    [ =11  =stable ]
#  34  lynis                    available    [ =stable ]
#  36  BCC                      available    [ =0.x  =stable ]
#  37  mono                     available    [ =5.x  =stable ]
#  38  nginx1                   available    [ =stable ]
#  40  mock                     available    [ =stable ]
#  41 †postgresql11             available    [ =11  =stable ]
#  43  livepatch                available    [ =stable ]
#  44 †python3.8=latest         enabled      [ =stable ]
#  45  haproxy2                 available    [ =stable ]
#  46  collectd                 available    [ =stable ]
#  47  aws-nitro-enclaves-cli   available    [ =stable ]
#  48  R4                       available    [ =stable ]
#   _  kernel-5.4               available    [ =stable ]
#  50  selinux-ng               available    [ =stable ]
#  51 †php8.0                   available    [ =stable ]
#  52  tomcat9                  available    [ =stable ]
#  53  unbound1.13              available    [ =stable ]
#  54 †mariadb10.5              available    [ =stable ]
#  55  kernel-5.10=latest       enabled      [ =stable ]
#  56  redis6                   available    [ =stable ]
#  57 †ruby3.0                  available    [ =stable ]
#  58 †postgresql12             available    [ =stable ]
#  59 †postgresql13             available    [ =stable ]
#  60  mock2                    available    [ =stable ]
#  61  dnsmasq2.85              available    [ =stable ]
#  62  kernel-5.15              available    [ =stable ]
#  63 †postgresql14             available    [ =stable ]
#  64  firefox                  available    [ =stable ]
#  65  lustre                   available    [ =stable ]
#  66 †php8.1                   available    [ =stable ]
#  67  awscli1                  available    [ =stable ]
#  68 †php8.2                   available    [ =stable ]
#  69  dnsmasq                  available    [ =stable ]
#  70  unbound1.17              available    [ =stable ]
#  71 †golang1.19               available    [ =stable ]
#  72  collectd-python3         available    [ =stable ]
# † Note on end-of-support. Use 'info' subcommand.
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# neuron                                                   | 2.9 kB     00:00
# 286 packages excluded due to repository priority protections
# No packages marked for update
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# neuron                                                   | 2.9 kB     00:00
# 286 packages excluded due to repository priority protections
# Package git-lfs-2.10.0-2.el7.x86_64 already installed and latest version
# Package git-2.40.1-1.amzn2.0.1.x86_64 already installed and latest version
# Nothing to do

# %%
import sagemaker
import boto3
sess = sagemaker.Session()
# sagemaker session bucket -> used for uploading data, models and logs
# sagemaker will automatically create this bucket if it not exists
sagemaker_session_bucket=None
if sagemaker_session_bucket is None and sess is not None:
    # set to default bucket if a bucket name is not given
    sagemaker_session_bucket = sess.default_bucket()

try:
    role = sagemaker.get_execution_role()
except ValueError:
    iam = boto3.client('iam')
    role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker role arn: arn:aws:iam::513489159680:role/NotebookStack-SmartSearchNotebookRole6F6BB12B-1CTP8VAQWQWYD
# sagemaker bucket: sagemaker-us-west-2-513489159680
# sagemaker session region: us-west-2

# %%
# !mkdir code

# %%
# %%writefile code/inference.py

from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

# Helper: Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


def model_fn(model_dir):
  # Load model from HuggingFace Hub
  tokenizer = AutoTokenizer.from_pretrained(model_dir)
  model = AutoModel.from_pretrained(model_dir)
  return model, tokenizer

def predict_fn(data, model_and_tokenizer):
    # destruct model and tokenizer
    model, tokenizer = model_and_tokenizer

    # Tokenize sentences
    sentences = data.pop("inputs", data)
    encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

    # return dictonary, which will be json serializable
    return sentence_embeddings.tolist()
# Out:
# Writing code/inference.py

# %%
repository = "BAAI/bge-large-zh"
model_id=repository.split("/")[-1]
s3_location=f"s3://{sess.default_bucket()}/custom_inference/{model_id}/model.tar.gz"

# %%
# !git lfs install
# !git clone https://huggingface.co/$repository
# Out:
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'bge-large-zh'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 59 (delta 9), reused 0 (delta 0), pack-reused 41
# Unpacking objects: 100% (59/59), 179.92 KiB | 5.62 MiB/s, done.
# Filtering content: 100% (2/2), 2.42 GiB | 83.03 MiB/s, done.

# %%
# !cp -r code/ $model_id/code/

# %%
# %cd $model_id
# !tar zcvf model.tar.gz *
# Out:
# /home/ec2-user/SageMaker/guidance-for-custom-search-of-an-enterprise-knowledge-base-on-aws/Embedding_Model/chinese_bge_large_zh/bge-large-zh
# 1_Pooling/
# 1_Pooling/config.json
# code/
# code/inference.py
# config.json
# config_sentence_transformers.json
# model.safetensors
# modules.json
# pytorch_model.bin
# README.md
# sentence_bert_config.json
# special_tokens_map.json
# tokenizer_config.json
# tokenizer.json
# vocab.txt

# %%
# !aws s3 cp model.tar.gz $s3_location
# Out:
# upload: ./model.tar.gz to s3://sagemaker-us-west-2-513489159680/custom_inference/bge-large-zh/model.tar.gz

# %%
import sagemaker
from sagemaker.huggingface.model import HuggingFaceModel

role = sagemaker.get_execution_role()

hub = {
	'HF_MODEL_ID':'BAAI/bge-large-zh',
	'HF_TASK':'feature-extraction'
}

# create Hugging Face Model Class
huggingface_model = HuggingFaceModel(
   model_data=s3_location,       # path to your model and script
   role=role,                    # iam role with permissions to create an Endpoint
   transformers_version="4.12",  # transformers version used
   pytorch_version="1.9",        # pytorch version used
   py_version='py38',            # python version used
   env=hub,
)

endpoint_name = 'huggingface-inference-eb'
# instance_type = 'ml.g4dn.2xlarge'
instance_type = 'ml.g4dn.xlarge'
instance_count = 1

# deploy the endpoint endpoint
from sagemaker.serializers import JSONSerializer
from sagemaker.deserializers import JSONDeserializer
predictor = huggingface_model.deploy(
    endpoint_name = endpoint_name,
    instance_type = instance_type, 
    initial_instance_count = instance_count,
    serializer = JSONSerializer(),
    deserializer = JSONDeserializer()
)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# ---------------!

# %%
# Inference testing
import time
import sagemaker
from sagemaker.huggingface import HuggingFaceModel

hfp = sagemaker.huggingface.model.HuggingFacePredictor('huggingface-inference-eb')

embedding = hfp.predict({'inputs':['测试一下']})[0]
print(embedding)
print(len(embedding))
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# [0.029940426349639893, -0.037013471126556396, -0.031123414635658264, -0.00795566476881504, -0.02059289440512657, -0.010724034160375595, -0.009407215751707554, -0.020607881247997284, 0.020763887092471123, 0.0005426029674708843, 0.019528184086084366, 0.013696566224098206, 0.027782544493675232, -0.039374109357595444, 0.016825107857584953, 0.022573012858629227, 0.018806667998433113, 0.008421698585152626, -0.008928587660193443, -0.03552060201764107, 0.003799907863140106, 0.005108044017106295, -0.003645034972578287, -0.02375832386314869, 0.01913130283355713, -0.012168528512120247, 0.026259852573275566, 0.042175643146038055, -0.0036501334980130196, -0.038215331733226776, -0.02504553832113743, 0.00783416535705328, 0.010248647071421146, 0.007178917992860079, 0.021235555410385132, -0.005305641796439886, -0.028929689899086952, 0.021273138001561165, 0.00803382508456707, -0.012115898542106152, 0.008113402873277664, -0.0048245275393128395, -0.030219998210668564, -0.023897942155599594, 0.01712973602116108, 0.023573830723762512, -0.05935649573802948, -0.03969297558069229, -0.009335082024335861, -0.005230356939136982, 0.027092741802334785, 0.016037670895457268, -0.00433984724804759, 0.0011147394543513656, -0.006320929620414972, 0.020635148510336876, -0.0020056581124663353, -0.01724581979215145, -0.010705167427659035, -0.024808945134282112, -0.03575776144862175, 0.25340887904167175, 0.0076903305016458035, -0.003918285947293043, -0.003376581007614732, 0.0012648935662582517, 0.000675451650749892, -0.04657874256372452, 0.0263061560690403, 0.012734100222587585, -0.004172454588115215, 0.011083398945629597, 0.033325351774692535, -0.006078645586967468, -0.0036051159258931875, 0.02135651186108589, 0.0032719688024371862, 0.011644858866930008, 0.005435428582131863, 0.01245549414306879, -0.00496705761179328, 0.0006856948602944613, 0.010770531371235847, -0.01970568671822548, 0.025355789810419083, -0.038507603108882904, 0.03313186392188072, 0.7031909227371216, -0.0007665202720090747, -0.010342692956328392, -0.012026550248265266, 0.037268538028001785, -0.01940969191491604, 0.011660292744636536, -0.0014034004416316748, -0.011867649853229523, -0.03883427754044533, -0.011708134785294533, 0.016204150393605232, -0.008245732635259628, 0.01073758490383625, -0.0026044477708637714, -0.03245909884572029, 0.0035979957319796085, -0.031924206763505936, 0.024021247401833534, -0.024150997400283813, -0.04227263107895851, -0.006570747122168541, -0.020708303898572922, 0.019963569939136505, -0.01327553577721119, -0.016071492806077003, -0.006203263998031616, -0.005228317808359861, -0.010670075193047523, 0.004843194968998432, 0.007698868867009878, 0.018647916615009308, 0.0004418652388267219, -0.014032725244760513, 0.02232421562075615, 0.002212820341810584, -0.00837156642228365, -0.015443687327206135, 0.01819715090095997, 0.01496035698801279, 0.00553049985319376, 0.04876900091767311, 0.014221473596990108, -0.004457531962543726, 0.007618427742272615, -0.0011238809674978256, 0.0046788109466433525, -0.03476923331618309, 0.02660324238240719, -0.005202733911573887, -0.01673666015267372, -0.013792255893349648, -0.0128279197961092, 0.02493075467646122, -0.02490868605673313, 0.008645547553896904, -0.015462610870599747, 0.028313959017395973, -0.04292701557278633, -0.0502762496471405, 0.021333452314138412, 0.016896067187190056, -0.025764785706996918, 0.0023604563903063536, -0.019444115459918976, -0.012993636541068554, -0.021184589713811874, -0.036958664655685425, -0.051330890506505966, 0.0006865125615149736, 0.002849854761734605, -0.007163054309785366, -0.006236998364329338, 0.016593310981988907, 0.004594900645315647, 0.010114424861967564, -0.02220846153795719, -0.040078580379486084, -0.028079845011234283, 0.01622721739113331, -0.039398979395627975, -0.006149349734187126, 0.0332786962389946, -0.03740852326154709, 0.03758934512734413, 0.010306972078979015, 0.0023373952135443687, 0.0334208719432354, -0.005524399224668741, -0.014027250930666924, 0.010844802483916283, -0.014008790254592896, -0 ...
# 1024
